# %% [markdown]
# <a href="https://colab.research.google.com/github/NafeesFathima6464/python_ad/blob/main/Day22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
data=pd.read_csv('/content/drive/MyDrive/NewspaperData.csv')

# %%
data.head()
# Out:
#             Newspaper    daily   sunday
# 0       Baltimore Sun  391.952  488.506
# 1        Boston Globe  516.981  798.298
# 2       Boston Herald  355.628  235.084
# 3  Charlotte Observer  238.555  299.451
# 4   Chicago Sun Times  537.780  559.093

# %%
data.tail()
# Out:
#                   Newspaper    daily    sunday
# 29  San Francisco Chronicle  570.364   704.322
# 30  St. Louis Post-Dispatch  391.286   585.681
# 31   St. Paul Pioneer Press  201.860   267.781
# 32            Tampa Tribune  321.626   408.343
# 33          Washington Post  838.902  1165.567

# %%
data.isnull().sum()
# Out:
# Newspaper    0
# daily        0
# sunday       0
# dtype: int64

# %%
data.sample()
# Out:
#        Newspaper    daily   sunday
# 14  Miami Herald  444.581  553.479

# %%
data.sample()
# Out:
#                      Newspaper   daily   sunday
# 16  New Orleans Times-Picayune  272.28  324.241

# %%
#sample will used to give any random rows from data

# %%
data.sample(6)
# Out:
#                          Newspaper    daily    sunday
# 5                  Chicago Tribune  733.775  1133.249
# 31          St. Paul Pioneer Press  201.860   267.781
# 28                  Sacramento Bee  273.844   338.355
# 22           Philadelphia Inquirer  515.523   982.663
# 30         St. Louis Post-Dispatch  391.286   585.681
# 26  Rochester Democrat & Chronicle  133.239   262.048

# %%
data.drop("Newspaper",axis=1).corr()
# Out:
#            daily    sunday
# daily   1.000000  0.958154
# sunday  0.958154  1.000000

# %% [markdown]
# #**Correlation**
