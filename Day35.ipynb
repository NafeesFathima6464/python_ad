# %% [markdown]
# <a href="https://colab.research.google.com/github/NafeesFathima6464/python_ad/blob/main/Day35.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##install the module
# !pip install streamlit

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,roc_auc_score,confusion_matrix

# %%
data=pd.read_csv('/content/Heart_Disease_Dataset.csv')

# %%
data.head()
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking  ... SleepTime  Asthma  KidneyDisease SkinCancer
# 0          Yes  14.96     Yes             Yes  ...      17.1     Yes            Yes        Yes
# 1          Yes  36.93     Yes             Yes  ...       2.7     Yes             No         No
# 2           No  18.70     Yes              No  ...      15.6     Yes            Yes        Yes
# 3          Yes  31.43     Yes             Yes  ...       1.4      No             No        Yes
# 4          Yes  75.64      No              No  ...       8.8     Yes            Yes        Yes
#
# [5 rows x 18 columns]

# %%
data.shape
# Out:
# (100201, 18)

# %%
data.describe()
# Out:
#                  BMI  PhysicalHealth   MentalHealth      SleepTime
# count  100201.000000   100201.000000  100201.000000  100201.000000
# mean       53.373302       14.503937      14.498239      12.490389
# std        23.878712        8.640423       8.658639       6.632122
# min        12.020000        0.000000       0.000000       1.000000
# 25%        32.760000        7.000000       7.000000       6.700000
# 50%        53.380000       14.000000      15.000000      12.500000
# 75%        73.950000       22.000000      22.000000      18.200000
# max        94.850000       29.000000      29.000000      24.000000

# %%
data.isnull().sum()
# Out:
# HeartDisease        0
# BMI                 0
# Smoking             0
# AlcoholDrinking     0
# Stroke              0
# PhysicalHealth      0
# MentalHealth        0
# DiffWalking         0
# Sex                 0
# AgeCategory         0
# Race                0
# Diabetic            0
# PhysicalActivity    0
# GenHealth           0
# SleepTime           0
# Asthma              0
# KidneyDisease       0
# SkinCancer          0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
len(data[data.duplicated()])
# Out:
# 0

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [HeartDisease, BMI, Smoking, AlcoholDrinking, Stroke, PhysicalHealth, MentalHealth, DiffWalking, Sex, AgeCategory, Race, Diabetic, PhysicalActivity, GenHealth, SleepTime, Asthma, KidneyDisease, SkinCancer]
# Index: []

# %%
##
for column in data.columns:
  print(data[column].value_counts())
# Out:
# HeartDisease
# Yes    50134
# No     50067
# Name: count, dtype: int64
# BMI
# 56.38    26
# 91.47    26
# 27.95    26
# 88.49    26
# 66.39    25
#          ..
# 23.75     3
# 29.15     3
# 65.14     3
# 34.33     2
# 91.36     2
# Name: count, Length: 8284, dtype: int64
# Smoking
# Yes    50445
# No     49756
# Name: count, dtype: int64
# AlcoholDrinking
# Yes    50435
# No     49766
# Name: count, dtype: int64
# Stroke
# Yes    50265
# No     49936
# Name: count, dtype: int64
# PhysicalHealth
# 8     3430
# 20    3401
# 9     3395
# 16    3392
# 19    3386
# 13    3385
# 12    3377
# 26    3369
# 29    3363
# 15    3355
# 23    3354
# 22    3347
# 28    3345
# 14    3343
# 2     3341
# 1     3337
# 10    3334
# 11    3332
# 6     3329
# 0     3328
# 17    3327
# 7     3323
# 24    3316
# 5     3305
# 18    3301
# 3     3287
# 21    3285
# 27    3277
# 25    3270
# 4     3267
# Name: count, dtype: int64
# MentalHealth
# 27    3442
# 16    3442
# 13    3419
# 5     3403
# ...
